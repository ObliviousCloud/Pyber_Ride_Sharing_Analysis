# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %%
city_data_df.head()
# Out:
#            city  driver_count   type
# 0   Richardfort            38  Urban
# 1  Williamsstad            59  Urban
# 2   Port Angela            67  Urban
# 3    Rodneyfort            34  Urban
# 4   West Robert            39  Urban

# %%
ride_data_df.head()
# Out:
#                  city                 date   fare        ride_id
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344

# %%
# Combine the data into a single dataset
# Display the data table for preview
merged_table = pd.merge(city_data_df, ride_data_df, on="city")
merged_table.head()
# Out:
#           city  driver_count   type                 date   fare        ride_id
# 0  Richardfort            38  Urban  2018-02-24 08:40:38  13.93  5628545007794
# 1  Richardfort            38  Urban  2018-02-13 12:46:07  14.00   910050116494
# 2  Richardfort            38  Urban  2018-02-16 13:52:19  17.92   820639054416
# 3  Richardfort            38  Urban  2018-02-01 20:18:28  10.26  9554935945413
# 4  Richardfort            38  Urban  2018-04-17 02:26:37  23.00   720020655850

# %%
merged_table.sort_values(by=['driver_count'], ascending=False).head()
# Out:
#                  city  driver_count   type                 date   fare  \
# 638  West Samuelburgh            73  Urban  2018-02-22 22:11:39  17.35
# 629  West Samuelburgh            73  Urban  2018-04-25 15:55:24  26.44
# 618  West Samuelburgh            73  Urban  2018-05-03 14:33:41  41.12
# 619  West Samuelburgh            73  Urban  2018-05-02 13:55:01  38.77
# 620  West Samuelburgh            73  Urban  2018-03-03 03:17:20  25.17
#
#            ride_id
# 638  3943007288125
# 629  4338654863099
# 618  7330842806458
# 619  2931685225267
# 620  1781749929829

# %%
ride_data_df.head()
# Out:
#                  city                 date   fare        ride_id
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344

# %%
#re-index rides by city
ride_reindexed_df = ride_data_df.set_index('city')
ride_reindexed_df.head()
# Out:
#                                    date   fare        ride_id
# city
# Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# Rodneyfort          2018-02-10 23:22:03  23.44  5149245426178
# South Jack          2018-03-06 04:28:35  34.58  3908451377344

# %%
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %%
#Average Fare per City
city_data = merged_table.groupby("city")
average_fare = (city_data['fare'].sum()/city_data["fare"].count()).round(2)
average_fare.head()
# Out:
# city
# Amandaburgh      24.64
# Barajasview      25.33
# Barronchester    36.42
# Bethanyland      32.96
# Bradshawfurt     40.06
# Name: fare, dtype: float64

# %%
#Total Number of Rides Per City
rides_per_city = merged_table["city"].value_counts()
rides_per_city.head()
# Out:
# West Angela        39
# South Karenland    38
# North Jason        35
# Port Frank         33
# Liumouth           33
# Name: city, dtype: int64

# %%
# Total Number of Drivers Per City
drivers_per_city = merged_table.groupby("city")["driver_count"].mean()
drivers_per_city.head()
# Out:
# city
# Amandaburgh      12
# Barajasview      26
# Barronchester    11
# Bethanyland      22
# Bradshawfurt      7
# Name: driver_count, dtype: int64

# %%
# City Type (Urban, Suburban, Rural)
#city_type = city_data_df["type"].unique()
#city_type

# %%
city_type = city_data_df.set_index('city')['type']
city_type.value_counts()
# Out:
# Urban       66
# Suburban    36
# Rural       18
# Name: type, dtype: int64

# %%
pyber = pd.DataFrame({"Average Fare Per City": average_fare,
                     "Number of Rides": rides_per_city,
                     "Number of Drivers": drivers_per_city,
                     "City Type": city_type})
pyber
# Out:
#                       Average Fare Per City City Type  Number of Drivers  \
# Amandaburgh                           24.64     Urban                 12
# Barajasview                           25.33     Urban                 26
# Barronchester                         36.42  Suburban                 11
# Bethanyland                           32.96  Suburban                 22
# Bradshawfurt                          40.06     Rural                  7
# Brandonfort                           35.44  Suburban                 10
# Carriemouth                           28.31     Urban                 52
# Christopherfurt                       24.50     Urban                 41
# Colemanland                           30.89  Suburban                 23
# Davidfurt                             32.00  Suburban                 23
# Deanville                             25.84     Urban                 49
# East Aaronbury                        25.66  Suburban                  7
# East Danielview                       31.56  Suburban                 22
# East Kaylahaven                       23.76     Urban                 65
# East Kentstad                         29.82  Suburban                 20
# East Marymouth                        30.84  Suburban                  5
# Erikaland                             24.91     Urban                 37
# Garzaport                             24.12     Rural                  7
# Grahamburgh                           25.22     Urban                 61
# Grayville                             27.76  Suburban                  2
# Harringtonfort                        33.47     Rural                  4
# Huntermouth                           28.99     Urban                 37
# Hurleymouth                           25.89     Urban                 36
# Jerryton                              25.65     Urban                 64
# Jessicaport                           36.01     Rural                  1
# Johnton                               26.79     Urban                 27
# Joneschester                          22.29     Urban                 39
# Josephside                            32.86  Suburban                 25
# Justinberg                            23.69     Urban                 39
# Karenberg                             26.34     Urban                 22
# ...                                     ...       ...                ...
# South Evanton                         26.73     Urban                 11
# South Jack                            22.97     Urban                 46
# South Jennifer                        35.26     Rural                  7
# South Karenland                       26.54     Urban                  4
# South Latoya                          20.09     Urban                 10
# South Marychester                     41.87     Rural                  1
# South Michelleport                    24.45     Urban                 72
# South Phillip                         28.57     Urban                 38
# South Saramouth                       36.16     Rural                  7
# South Teresa                          31.22  Suburban                 21
# Taylorhaven                           42.26     Rural                  1
# Valentineton                          24.64     Urban                 45
# Veronicaberg                          32.83  Suburban                 20
# Victoriaport                          27.78  Suburban                 16
# West Angela                           25.99     Urban                 48
# West Anthony                          24.74     Urban                 70
# West Christopherberg                  24.42     Urban                 32
# West Ericstad                         22.35     Urban                 25
# West Gabriel                          20.35     Urban                 57
# West Hannah                           29.55  Suburban                 12
# West Heather                          33.89     Rural                  4
# West Heidi                            23.13     Urban                 28
# West Josephberg                       21.72     Urban                 45
# West Kimmouth                         29.87  Suburban                  4
# West Patrickchester                   28.23     Urban                 25
# West Robert                           25.12     Urban                 39
# West Samuelburgh                      21.77     Urban                 73
# Williamsonville                       31.87  Suburban                  2
# Williamsstad                          24.36     Urban                 59
# Williamsview                          26.60     Urban                 46
#
#                       Number of Rides
# Amandaburgh                        18
# Barajasview                        22
# Barronchester                      16
# Bethanyland                        18
# Bradshawfurt                       10
# Brandonfort                        19
# Carriemouth                        27
# Christopherfurt                    27
# Colemanland                        22
# Davidfurt                          17
# Deanville                          19
# East Aaronbury                      9
# East Danielview                    17
# East Kaylahaven                    29
# East Kentstad                      13
# East Marymouth                     27
# Erikaland                          12
# Garzaport                           3
# Grahamburgh                        25
# Grayville                          15
# Harringtonfort                      6
# Huntermouth                        24
# Hurleymouth                        28
# Jerryton                           25
# Jessicaport                         6
# Johnton                            21
# Joneschester                       25
# Josephside                         27
# Justinberg                         30
# Karenberg                          17
# ...                               ...
# South Evanton                      31
# South Jack                         19
# South Jennifer                      7
# South Karenland                    38
# South Latoya                       19
# South Marychester                   8
# South Michelleport                 31
# South Phillip                      31
# South Saramouth                     4
# South Teresa                       22
# Taylorhaven                         6
# Valentineton                       22
# Veronicaberg                       17
# Victoriaport                       14
# West Angela                        39
# West Anthony                       30
# West Christopherberg               26
# West Ericstad                      18
# West Gabriel                       23
# West Hannah                        21
# West Heather                        9
# West Heidi                         28
# West Josephberg                    26
# West Kimmouth                      20
# West Patrickchester                16
# West Robert                        31
# West Samuelburgh                   25
# Williamsonville                    14
# Williamsstad                       23
# Williamsview                       20
#
# [120 rows x 4 columns]

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types
urban_df = pyber.loc[pyber["City Type"] =="Urban"]
suburban_df = pyber.loc[pyber["City Type"] == "Suburban"]
rural_df = pyber.loc[pyber["City Type"] == "Rural"]

# Build the scatter plots for each city types
plt.scatter(urban_df["Number of Rides"], urban_df["Average Fare Per City"], s=urban_df["Number of Drivers"]*7, 
c="coral", edgecolor = "black", label = "Urban",alpha=1, linewidth=1)
plt.scatter(suburban_df["Number of Rides"], suburban_df["Average Fare Per City"], s=suburban_df["Number of Drivers"]*7, 
c="lightblue", label = "Suburban", edgecolor = "black", alpha=1, linewidth=1)
plt.scatter(rural_df["Number of Rides"], rural_df["Average Fare Per City"], s=rural_df["Number of Drivers"]*7, 
c="gold", label = "Rural", edgecolor = "black", alpha=1, linewidth=1)

# Incorporate the other graph properties
plt.title("Pyber Ride Sharing Data(2016)")
plt.xlabel("Number of Rides")
plt.ylabel("Average Fare Per City")

# Create a legend
lgd = plt.legend(labels=["Urban", "Suburban","Rural"], loc="best", title="City Types")
plt.legend(loc="best")
plt.grid()
# Incorporate a text label regarding circle size

# Save Figure
#plt.savefi

# %%
# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents

# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents

# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents

# Build Pie Charts

# Save Figure

# %%
# Show Figure
plt.show()
